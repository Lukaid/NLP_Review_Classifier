# %% [markdown]
# ### 쿠팡 스크래핑 _ 구글 플레이 스토어

# %%
import requests
import urllib.request
# from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

import time
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36",
    "Accept-Language": "ko-KR,ko"  # 이렇게 써줘야 한글 페이지를 반환해줌
}

url = "https://play.google.com/store/apps/details?id=com.coupang.mobile&showAllReviews=true"
# res = requests.get(url, headers=headers)
# res.raise_for_status()
# soup = BeautifulSoup(res.text, "lxml")

browser = webdriver.Chrome()
browser.maximize_window()
browser.get(url)

time.sleep(10)  # 이때 관련성순에서 최신순으로 바꿔주기

data = pd.DataFrame(data=[], columns=['num', 'date',
                    'review', 'rating', 'like'])

k = 0
while True:
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2) 
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    while True:
        try:
            browser.find_element_by_xpath(
                '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div').click()
            k += 1
            print(f'더보기 횟수 : {k}번')
            print(f'나타난 리뷰 수 : {40 + k*160}')
            break
        except:
            browser.execute_script(
                "window.scrollTo(0, document.body.scrollHeight - 500)")
            browser.execute_script(
                "window.scrollTo(0, document.body.scrollHeight)")
            time.sleep(2)
    if k * 160 >= 60000:
        break


print('데이터 수집 시작')
reviews = browser.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser.find_elements_by_css_selector('.jUL89d')
dates = browser.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data.columns)
    data = pd.concat([data, tmp])
    if i % 100 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data.to_csv('data_coupang.csv', encoding='utf-8-sig')
print('스크래핑 완료')
# Out:
# 더보기 횟수 : 56번
# 나타난 리뷰 수 : 9000
# 더보기 횟수 : 57번
# 나타난 리뷰 수 : 9160
# 더보기 횟수 : 58번
# 나타난 리뷰 수 : 9320
# 더보기 횟수 : 59번
# 나타난 리뷰 수 : 9480
# 더보기 횟수 : 60번
# 나타난 리뷰 수 : 9640
# 더보기 횟수 : 61번
# 나타난 리뷰 수 : 9800
# 더보기 횟수 : 62번
# 나타난 리뷰 수 : 9960
# 더보기 횟수 : 63번
# 나타난 리뷰 수 : 10120
# 더보기 횟수 : 64번
# 나타난 리뷰 수 : 10280
# 더보기 횟수 : 65번
# 나타난 리뷰 수 : 10440
# 더보기 횟수 : 66번
# 나타난 리뷰 수 : 10600
# 더보기 횟수 : 67번
# 나타난 리뷰 수 : 10760
# 더보기 횟수 : 68번
# 나타난 리뷰 수 : 10920
# 더보기 횟수 : 69번
# 나타난 리뷰 수 : 11080
# 더보기 횟수 : 70번
# 나타난 리뷰 수 : 11240
# 더보기 횟수 : 71번
# 나타난 리뷰 수 : 11400
# 더보기 횟수 : 72번
# 나타난 리뷰 수 : 11560
# 더보기 횟수 : 73번
# 나타난 리뷰 수 : 11720
# 더보기 횟수 : 74번
# 나타난 리뷰 수 : 11880
# 더보기 횟수 : 75번
# 나타난 리뷰 수 : 12040
# 더보기 횟수 : 76번
# 나타난 리뷰 수 : 12200
# 더보기 횟수 : 77번
# 나타난 리뷰 수 : 12360
# 더보기 횟수 : 78번
# 나타난 리뷰 수 : 12520
# 더보기 횟수 : 79번
# 나타난 리뷰 수 : 12680
# 더보기 횟수 : 80번
# 나타난 리뷰 수 : 12840
# 더보기 횟수 : 81번
# 나타난 리뷰 수 : 13000
# 더보기 횟수 : 82번
# 나타난 리뷰 수 : 13160
# 더보기 횟수 : 83번
# 나타난 리뷰 수 : 13320
# 더보기 횟수 : 84번
# 나타난 리뷰 수 : 13480
# 더보기 횟수 : 85번
# ...

# %% [markdown]
# - 23:25 시작

# %%
print('데이터 수집 시작')
reviews = browser.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser.find_elements_by_css_selector('.jUL89d')
dates = browser.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data.columns)
    data = pd.concat([data, tmp])

data.to_csv('data_coupang.csv', encoding='utf-8-sig')
# Out:
# 데이터 수집 시작
# 객체생성 완료

# %% [markdown]
# ### 롯데on 스크래핑 _ 구글 플레이 스토어

# %%
import requests
import urllib.request
from selenium import webdriver
from selenium.webdriver.common.by import By

import time
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36",
    "Accept-Language": "ko-KR,ko"  # 이렇게 써줘야 한글 페이지를 반환해줌
}

url = "https://play.google.com/store/apps/details?id=com.lotte&showAllReviews=true"

browser_lt = webdriver.Chrome()
browser_lt.maximize_window()
browser_lt.get(url)

time.sleep(10)  # 이때 관련성순에서 최신순으로 바꿔주기

data_lt = pd.DataFrame(data=[], columns=['num', 'date', 'review', 'rating', 'like'])

k = 0
while True:
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_lt.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    while True:
        try:
            browser_lt.find_element_by_xpath(
                '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div').click()
            k += 1
            print(f'더보기 횟수 : {k}번')
            print(f'나타난 리뷰 수 : {40 + k*160}')
            break
        except:
            browser_lt.execute_script(
                "window.scrollTo(0, document.body.scrollHeight - 500)")
            browser_lt.execute_script(
                "window.scrollTo(0, document.body.scrollHeight)")
            time.sleep(2)
    if k * 160 >= 1000:
        break

print('데이터 수집 시작')
reviews = browser_lt.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser_lt.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser_lt.find_elements_by_css_selector('.jUL89d')
dates = browser_lt.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data_lt.columns)
    data_lt = pd.concat([data_lt, tmp])
    if i % 1000 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data_lt.to_csv('data_lt.csv', encoding='utf-8-sig')
# Out:
# 더보기 횟수 : 1번
# 나타난 리뷰 수 : 200
# 더보기 횟수 : 2번
# 나타난 리뷰 수 : 360
# 더보기 횟수 : 3번
# 나타난 리뷰 수 : 520
# 더보기 횟수 : 4번
# 나타난 리뷰 수 : 680
# 더보기 횟수 : 5번
# 나타난 리뷰 수 : 840
# 더보기 횟수 : 6번
# 나타난 리뷰 수 : 1000
# 더보기 횟수 : 7번
# 나타난 리뷰 수 : 1160
# 데이터 수집 시작
# 객체생성 완료
# 0번째 리뷰 저장 완료
# 1000번째 리뷰 저장 완료

# %% [markdown]
# ### SSG 스크래핑 _ 구글 플레이 스토어

# %%
import requests
import urllib.request
from selenium import webdriver
from selenium.webdriver.common.by import By

import time
import pandas as pd

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36",
    "Accept-Language": "ko-KR,ko"  # 이렇게 써줘야 한글 페이지를 반환해줌
}

url = "https://play.google.com/store/apps/details?id=kr.co.ssg&showAllReviews=true"

browser_ssg = webdriver.Chrome()
browser_ssg.maximize_window()
browser_ssg.get(url)

time.sleep(10)  # 이때 관련성순에서 최신순으로 바꿔주기

data_ssg = pd.DataFrame(data=[], columns=['num', 'date', 'review', 'rating', 'like'])

k = 0
while True:
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    browser_ssg.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(2)
    while True:
        try:
            browser_ssg.find_element_by_xpath(
                '//*[@id="fcxH9b"]/div[4]/c-wiz/div/div[2]/div/div/main/div/div[1]/div[2]/div[2]/div').click()
            k += 1
            print(f'더보기 횟수 : {k}번')
            print(f'나타난 리뷰 수 : {40 + k*160}')
            break
        except:
            browser_ssg.execute_script(
                "window.scrollTo(0, document.body.scrollHeight - 500)")
            browser_ssg.execute_script(
                "window.scrollTo(0, document.body.scrollHeight)")
            time.sleep(2)
    if k * 160 >= 1000:
        break

print('데이터 수집 시작')
reviews = browser_ssg.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser_ssg.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser_ssg.find_elements_by_css_selector('.jUL89d')
dates = browser_ssg.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data_ssg.columns)
    data_ssg = pd.concat([data_ssg, tmp])
    if i % 1000 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data_ssg.to_csv('data_ssg.csv', encoding='utf-8-sig')
# Out:
# 더보기 횟수 : 1번
# 나타난 리뷰 수 : 200
# 더보기 횟수 : 2번
# 나타난 리뷰 수 : 360
# 더보기 횟수 : 3번
# 나타난 리뷰 수 : 520
# 더보기 횟수 : 4번
# 나타난 리뷰 수 : 680
# 더보기 횟수 : 5번
# 나타난 리뷰 수 : 840
# 더보기 횟수 : 6번
# 나타난 리뷰 수 : 1000
# 더보기 횟수 : 7번
# 나타난 리뷰 수 : 1160
# 데이터 수집 시작
# 객체생성 완료
# 0번째 리뷰 저장 완료
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-43d8fbe470cc> in <module>
#      63     tmp.append(reviews[i].text)
#      64     tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
# ---> 65     tmp.append(ddabong[i].text)
#      66
#      67     tmp = pd.DataFrame(data=[tmp], columns=data_ssg.columns)
#
# C:\Python39\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ...

# %%
print('데이터 수집 시작')
reviews = browser_ssg.find_elements_by_css_selector('.UD7Dzf')
star_grades = browser_ssg.find_elements_by_xpath(
    '//div[@class="pf5lIe"]/div[@role="img"]')
ddabong = browser_ssg.find_elements_by_css_selector('.jUL89d')
dates = browser_ssg.find_elements_by_css_selector('.p2TkOb')
print('객체생성 완료')

for i in range(len(reviews)):
    tmp = []
    tmp.append(i)
    tmp.append(dates[i].text)
    tmp.append(reviews[i].text)
    tmp.append(star_grades[i+1].get_attribute('aria-label')[10])
    tmp.append(ddabong[i].text)

    tmp = pd.DataFrame(data=[tmp], columns=data_ssg.columns)
    data_ssg = pd.concat([data_ssg, tmp])
    if i % 1000 == 0:
        print(f'{i}번째 리뷰 저장 완료')

data_ssg.to_csv('data_ssg.csv', encoding='utf-8-sig')
# Out:
# 데이터 수집 시작
# 객체생성 완료
# 0번째 리뷰 저장 완료
# 1000번째 리뷰 저장 완료
